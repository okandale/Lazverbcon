# %%
# %pip uninstall -y pyarrow
# %pip install pyarrow
# Out:
# Found existing installation: pyarrow 23.0.1
# Uninstalling pyarrow-23.0.1:
#   Successfully uninstalled pyarrow-23.0.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting pyarrow
#   Using cached pyarrow-23.0.1-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Using cached pyarrow-23.0.1-cp311-cp311-win_amd64.whl (27.5 MB)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-23.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %%
# %pip install psycopg2-binary sqlalchemy pandas
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\adam\anaconda3\lib\site-packages (2.9.11)
# Requirement already satisfied: sqlalchemy in c:\users\adam\anaconda3\lib\site-packages (2.0.25)
# Requirement already satisfied: pandas in c:\users\adam\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\adam\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\adam\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\adam\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adam\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adam\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\adam\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\adam\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
engine = create_engine(
    "postgresql+psycopg2://postgres:1620@localhost:5432/laz_test"
)
pd.read_sql("SELECT 1;", engine)
# Out:
#    ?column?
# 0         1

# %%
import pandas as pd

path = r"Test Verb Present tense.csv"   # adjust path if needed
raw = pd.read_csv(path, low_memory=False)

# keep only non-empty column names that aren't "Unnamed: ..."
df = raw.loc[:, ~raw.columns.str.startswith("Unnamed:")].copy()

df.columns
df.head()
# Out:
#   Laz Infinitive Category Laz 3rd Person Singular Present          Region  \
# 0  avara doskudu      TVM                  avara doskudun  PZ, AŞ, FA, HO
# 1        cebazgu      TVE                       cobazgams          PZ, AŞ
# 2        cebgaru      TVE                         cabgars              PZ
# 3         ceçamu      TVE                          ceçams          PZ, AŞ
# 4          ceç̌u      TVE                         coç̌ams          PZ, AŞ
#
#   Laz 3rd Person Singular Present Alternative 1 Region Alternative 1  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
# 3                                           NaN                  NaN
# 4                                           NaN                  NaN
#
#   Laz 3rd Person Singular Present Alternative 2 Region Alternative 2  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
# 3                                           NaN                  NaN
# 4                                           NaN                  NaN
#
#               English Translation       Turkish Verb  verb_family_id
# 0                      to be idle       avare kalmak              19
# 1  to press, to step on something             basmak             139
# 2        to lament over something        ağıt yakmak             108
# 3        to hit something/someone  vurmak (bir şeye)              98
# 4                        to begin           başlamak              28

# %%
# clean + unique category codes
cats = (
    df[["Category"]]
    .dropna()
    .assign(code=lambda x: x["Category"].astype(str).str.strip())
    .drop_duplicates(subset=["code"])
    [["code"]]
)

# explicit mappings
english_map = {
    "IVD": "Dative verb",
    "TVM": "Nominative verb",
    "TVE": "Ergative verb",
}

turkish_map = {
    "IVD": "Yönelme fiili",
    "TVM": "Nominatif fiili",
    "TVE": "Ergatif fiili",
}

cats["english_name"] = cats["code"].map(english_map)
cats["turkish_name"] = cats["code"].map(turkish_map)

# final column order
cats = cats[["english_name", "turkish_name", "code"]]

cats
# Out:
#       english_name     turkish_name code
# 0  Nominative verb  Nominatif fiili  TVM
# 1    Ergative verb    Ergatif fiili  TVE
# 7      Dative verb    Yönelme fiili  IVD

# %%
pd.read_sql("""
SELECT column_name, is_nullable
FROM information_schema.columns
WHERE table_name = 'verb_category'
ORDER BY ordinal_position;
""", engine)
# Out:
#         column_name is_nullable
# 0  verb_category_id          NO
# 1      english_name          NO
# 2      turkish_name          NO
# 3              code          NO

# %%
cats.to_sql("verb_category", engine, if_exists="append", index=False) # double check, verb groups should be unique
# Out:
# 3

# %%
pd.read_sql("SELECT * FROM verb_category ORDER BY verb_category_id;", engine)
# Out:
#      verb_category_id     english_name     turkish_name code
# 0                   1  Nominative verb  Nominatif fiili  TVM
# 1                   2    Ergative verb    Ergatif fiili  TVE
# 2                   3      Dative verb    Yönelme fiili  IVD
# 3                   4  Nominative verb  Nominatif fiili  TVM
# 4                   5    Ergative verb    Ergatif fiili  TVE
# ..                ...              ...              ...  ...
# 103               104    Ergative verb    Ergatif fiili  TVE
# 104               105      Dative verb    Yönelme fiili  IVD
# 105               106  Nominative verb  Nominatif fiili  TVM
# 106               107    Ergative verb    Ergatif fiili  TVE
# 107               108      Dative verb    Yönelme fiili  IVD
#
# [108 rows x 4 columns]

# %%
cat_map = pd.read_sql("SELECT verb_category_id, code FROM verb_category;", engine)
cat_map
# Out:
#      verb_category_id code
# 0                   1  TVM
# 1                   2  TVE
# 2                   3  IVD
# 3                   4  TVM
# 4                   5  TVE
# ..                ...  ...
# 103               104  TVE
# 104               105  IVD
# 105               106  TVM
# 106               107  TVE
# 107               108  IVD
#
# [108 rows x 2 columns]

# %%
# 1) build verbs from the CSV
verbs = (
    df[["Laz Infinitive", "Category"]]
    .dropna()
    .assign(
        infinitive=lambda x: x["Laz Infinitive"].astype(str).str.strip(),
        code=lambda x: x["Category"].astype(str).str.strip(),
    )
    .query("infinitive != ''")
    .drop_duplicates(subset=["infinitive", "code"])
    .merge(cat_map, on="code", how="left") # why is this necessary? Is it to get the verb category ID?
)

# 2) sanity check: any categories that didn't map?
bad = verbs[verbs["verb_category_id"].isna()][["infinitive", "code"]].drop_duplicates() 
bad
# Out:
# Empty DataFrame
# Columns: [infinitive, code]
# Index: []

# %%
dialects = pd.DataFrame([
    {"english_name": "Ardeşen", "turkish_name": "Ardeşen", "laz_name": "Art̆aşeni"},
    {"english_name": "Pazar", "turkish_name": "Pazar", "laz_name": "Atina"},
    {"english_name": "Fındıklı/Arhavi", "turkish_name": "Fındıklı/Arhavi", "laz_name": "Viǯe/Arkabi"},
    {"english_name": "Hopa", "turkish_name": "Hopa", "laz_name": "Xopa"},
])
dialects
# Out:
#       english_name     turkish_name     laz_name
# 0          Ardeşen          Ardeşen    Art̆aşeni
# 1            Pazar            Pazar        Atina
# 2  Fındıklı/Arhavi  Fındıklı/Arhavi  Viǯe/Arkabi
# 3             Hopa             Hopa         Xopa

# %%
existing = pd.read_sql("SELECT english_name FROM dialect;", engine)

dialects_new = dialects[~dialects["english_name"].isin(existing["english_name"])].copy() #
dialects_new
# Out:
# Empty DataFrame
# Columns: [english_name, turkish_name, laz_name]
# Index: []

# %%
dialects_new.to_sql("dialect", engine, if_exists="append", index=False)
# Out:
# 0

# %%
from sqlalchemy import text

with engine.begin() as conn:
    conn.execute(
        text("""
        UPDATE dialect
        SET laz_name = 'Art̆aşeni'
        WHERE english_name = 'Ardeşen';
        """)
    )

# %%
pd.read_sql(
    "SELECT dialect_id, english_name, turkish_name, laz_name FROM dialect ORDER BY dialect_id;",
    engine
)
# Out:
#    dialect_id     english_name     turkish_name     laz_name
# 0           1          Ardeşen          Ardeşen    Art̆aşeni
# 1           2            Pazar            Pazar        Atina
# 2           3  Fındıklı/Arhavi  Fındıklı/Arhavi  Viǯe/Arkabi
# 3           4             Hopa             Hopa         Xopa

# %%
DEFAULT_DIALECT_ID = int(pd.read_sql(
    "SELECT dialect_id FROM dialect WHERE english_name='Fındıklı/Arhavi';",
    engine
).iloc[0,0])
DEFAULT_DIALECT_ID
# Out:
# 3

# %%
verbs = (
    df[["Laz Infinitive", "Category"]]
    .dropna()
    .assign(
        infinitive=lambda x: x["Laz Infinitive"].astype(str).str.strip(),
        code=lambda x: x["Category"].astype(str).str.strip(),
    )
    .query("infinitive != ''")
    .drop_duplicates(subset=["infinitive", "code"])
    .merge(cat_map, on="code", how="left")
)

# must be empty
verbs[verbs["verb_category_id"].isna()]
# Out:
# Empty DataFrame
# Columns: [Laz Infinitive, Category, infinitive, code, verb_category_id]
# Index: []

# %%
pd.read_sql("""
SELECT column_name, is_nullable
FROM information_schema.columns
WHERE table_name = 'verb'
ORDER BY ordinal_position;
""", engine)
# Out:
#                 column_name is_nullable
# 0                   verb_id          NO
# 1            verb_family_id         YES
# 2                dialect_id          NO
# 3          verb_category_id          NO
# 4                infinitive          NO
# 5               present_3sg          NO
# 6           meaning_english          NO
# 7           meaning_turkish          NO
# 8           requires_marker          NO
# 9   has_optional_preverb_ko          NO
# 10  has_optional_preverb_do          NO

# %%
COL_INF = "Laz Infinitive"
COL_CAT = "Category"
COL_PRES3 = "Laz 3rd Person Singular Present"
COL_ENG = "English Translation"
COL_TR  = "Turkish Verb"

verbs = (
    df[[COL_INF, COL_CAT, COL_PRES3, COL_ENG, COL_TR]]
    .dropna(subset=[COL_INF, COL_CAT, COL_PRES3, COL_ENG, COL_TR])
    .assign(
        infinitive=lambda x: x[COL_INF].astype(str).str.strip(),
        code=lambda x: x[COL_CAT].astype(str).str.strip(),
        present_3sg=lambda x: x[COL_PRES3].astype(str).str.strip(),
        meaning_english=lambda x: x[COL_ENG].astype(str).str.strip(),
        meaning_turkish=lambda x: x[COL_TR].astype(str).str.strip(),
    )
    .query("infinitive != '' and present_3sg != '' and meaning_english != '' and meaning_turkish != ''")
    .drop_duplicates(subset=["infinitive", "code"]) # why drop these duplicates; not necessary at this stage (remove)
    .merge(cat_map, on="code", how="left")
)

# sanity: should be empty
missing = verbs[verbs["verb_category_id"].isna()]
missing
# Out:
# Empty DataFrame
# Columns: [Laz Infinitive, Category, Laz 3rd Person Singular Present, English Translation, Turkish Verb, infinitive, code, present_3sg, meaning_english, meaning_turkish, verb_category_id]
# Index: []

# %%
pd.read_sql("SELECT COUNT(*) AS n_verbs FROM verb;", engine)
# Out:
#    n_verbs
# 0      653

# %%
df.shape
# Out:
# (327, 11)

# %%
df[["Laz Infinitive","Category","Laz 3rd Person Singular Present","English Translation","Turkish Verb","Region"]].head(10)
# Out:
#   Laz Infinitive Category Laz 3rd Person Singular Present  \
# 0  avara doskudu      TVM                  avara doskudun
# 1        cebazgu      TVE                       cobazgams
# 2        cebgaru      TVE                         cabgars
# 3         ceçamu      TVE                          ceçams
# 4          ceç̌u      TVE                         coç̌ams
# 5         cegapu      TVM                           cagen
# 6         ceginu      TVE                        coginams
# 7        cedginu      IVD                        cadginen
# 8       celabalu      TVE                        celabams
# 9       cemp̌onu      TVE                      comp̌onams
#
#                              English Translation       Turkish Verb  \
# 0                                     to be idle       avare kalmak
# 1                 to press, to step on something             basmak
# 2                       to lament over something        ağıt yakmak
# 3                       to hit something/someone  vurmak (bir şeye)
# 4                                       to begin           başlamak
# 5                                 to get used to            alışmak
# 6  to get someone become familiar with something         alıştırmak
# 7                                       to crave            aşermek
# 8                                        to hang              asmak
# 9                         to vaccinate/fertilize           aşılamak
#
#            Region
# 0  PZ, AŞ, FA, HO
# 1          PZ, AŞ
# 2              PZ
# 3          PZ, AŞ
# 4          PZ, AŞ
# 5          PZ, AŞ
# 6          PZ, AŞ
# 7          PZ, AŞ
# 8          PZ, AŞ
# 9              AŞ

# %%
COL_INF="Laz Infinitive"
COL_CAT="Category"
COL_PRES3="Laz 3rd Person Singular Present"
COL_ENG="English Translation"
COL_TR="Turkish Verb"
COL_REG="Region"

verbs = (
    df[[COL_INF, COL_CAT, COL_PRES3, COL_ENG, COL_TR, COL_REG]]
    .assign(
        infinitive=lambda x: x[COL_INF].astype(str).str.strip(),
        code=lambda x: x[COL_CAT].astype(str).str.strip(),
        present_3sg=lambda x: x[COL_PRES3].astype(str).str.strip(),
        meaning_english=lambda x: x[COL_ENG].astype(str).str.strip(),
        meaning_turkish=lambda x: x[COL_TR].astype(str).str.strip(),
        region=lambda x: x[COL_REG].astype(str).str.strip(),
    )
)

verbs.shape
# Out:
# (327, 12)

# %%
verbs[["infinitive","code","present_3sg","meaning_english","meaning_turkish","region"]].isna().sum()
# Out:
# infinitive         0
# code               0
# present_3sg        0
# meaning_english    0
# meaning_turkish    0
# region             0
# dtype: int64

# %%
usable = verbs.query("infinitive != '' and code != '' and present_3sg != ''")
usable.shape
# Out:
# (327, 12)

# %%
import pandas as pd

cat_map = pd.read_sql("SELECT verb_category_id, code FROM verb_category;", engine)

dialect_map = pd.read_sql("SELECT dialect_id, english_name FROM dialect;", engine)

# region code -> dialect english_name
region_to_english = {
    "AŞ": "Ardeşen",
    "PZ": "Pazar",
    "FA": "Fındıklı/Arhavi",
    "HO": "Hopa",
}

# turn dialect_map into english_name -> dialect_id
english_to_id = dict(zip(dialect_map["english_name"], dialect_map["dialect_id"]))

# final region code -> dialect_id
region_to_id = {k: english_to_id[v] for k, v in region_to_english.items()}
region_to_id
# Out:
# {'AŞ': 1, 'PZ': 2, 'FA': 3, 'HO': 4}

# %% [markdown]
# ### Important terminology note
# - **verb_family**: groups related lexical roots across dialects (e.g., *uqoun* ~ *uyonun* “to have”).
# - **preverb variants** (e.g., *obaru*, *mebaru*, *ebaru*): should **not** be grouped via `verb_family_id`.
#   If/when you add a CSV column like `preverb_family` (e.g., `obaru`), we can seed a `preverb_family` table and link verbs to it via `preverb_family_id`.

# %%
COL_INF="Laz Infinitive"
COL_CAT="Category"
COL_PRES3="Laz 3rd Person Singular Present"
COL_ENG="English Translation"
COL_TR="Turkish Verb"
COL_REG="Region"
COL_FAM ="verb_family_id"
# Optional column: preverb_family (groups preverb variants like obaru/mebaru/ebaru).
# If not present in the CSV, it will be treated as missing.
COL_PREFAM="preverb_family"
if COL_PREFAM not in df.columns:
    df[COL_PREFAM] = pd.NA

verbs = (
    df[[COL_INF, COL_CAT, COL_PRES3, COL_ENG, COL_TR, COL_REG, COL_FAM, COL_PREFAM]]
    .assign(
        infinitive=lambda x: x[COL_INF].astype(str).str.strip(),
        code=lambda x: x[COL_CAT].astype(str).str.strip(),
        present_3sg=lambda x: x[COL_PRES3].astype(str).str.strip(),
        meaning_english=lambda x: x[COL_ENG].astype(str).str.strip(),
        meaning_turkish=lambda x: x[COL_TR].astype(str).str.strip(),
        region=lambda x: x[COL_REG].astype(str).str.strip(),
        verb_family_id=lambda x: pd.to_numeric(x[COL_FAM], errors="coerce").astype("Int64"),
        preverb_family=lambda x: x[COL_PREFAM].astype(str).str.strip().replace({"": pd.NA, "nan": pd.NA}),
    )
    .query("infinitive != '' and code != '' and present_3sg != ''")
    .merge(cat_map, on="code", how="left")
)

# split "PZ, AŞ, FA" -> ["PZ","AŞ","FA"]
verbs = verbs.assign(
    region_code=lambda x: x["region"].str.split(",")
).explode("region_code")

verbs["region_code"] = verbs["region_code"].astype(str).str.strip()

# map to dialect_id
verbs["dialect_id"] = verbs["region_code"].map(region_to_id)

# sanity check: should be empty
bad = verbs[verbs["dialect_id"].isna()][["region","region_code"]].drop_duplicates()
bad
# Out:
# Empty DataFrame
# Columns: [region, region_code]
# Index: []

# %%
# --- Build verbs_to_insert to match your verb table ---

# If verbs_clean already exists from earlier cells, use it.
# Otherwise, create it from verbs (this makes the cell self-contained).
if "verbs_clean" in globals():
    base = verbs_clean.copy()
else:
    base = verbs.dropna(subset=["dialect_id", "verb_category_id"]).copy()

# ensure FK ints (verb_family_id can be NULL, so keep it as nullable Int64)
base["dialect_id"] = base["dialect_id"].astype(int)
base["verb_category_id"] = base["verb_category_id"].astype(int)

# Only do this if the column exists (prevents KeyError if you forgot the earlier step)
if "verb_family_id" in base.columns:
    base["verb_family_id"] = base["verb_family_id"].astype("Int64")
else:
    # If you hit this, it means the earlier "verbs =" cell didn't create verb_family_id
    raise KeyError("verb_family_id column is missing. Make sure your earlier step creates it from the CSV.")

verbs_to_insert = (
    base[[
        "verb_family_id",      # Cross-dialect lexical root group (uqoun ~ uyonun). Not preverb mapping.
        "verb_category_id",
        "dialect_id",
        "infinitive",
        "present_3sg",
        "meaning_english",
        "meaning_turkish",
    ]]
    .drop_duplicates()
    .copy()
)

# required booleans (set defaults for now; you can refine later)
verbs_to_insert["requires_marker"] = False


# IMPORTANT: de-dupe on your conflict target (dialect_id, infinitive)
verbs_to_insert = verbs_to_insert.drop_duplicates(subset=["dialect_id", "infinitive"])

verbs_to_insert.head()
# Out:
#     verb_family_id  verb_category_id  dialect_id     infinitive  \
# 0               19                 1           2  avara doskudu
# 0               19                 1           1  avara doskudu
# 0               19                 1           3  avara doskudu
# 0               19                 1           4  avara doskudu
# 36             139                 2           2        cebazgu
#
#        present_3sg                 meaning_english meaning_turkish  \
# 0   avara doskudun                      to be idle    avare kalmak
# 0   avara doskudun                      to be idle    avare kalmak
# 0   avara doskudun                      to be idle    avare kalmak
# 0   avara doskudun                      to be idle    avare kalmak
# 36       cobazgams  to press, to step on something          basmak
#
#     requires_marker
# 0             False
# 0             False
# 0             False
# 0             False
# 36            False

# %%
# --- Ensure verb_family rows exist (needed before inserting verbs with verb_family_id FK) ---
# Because schema.sql defines verb_family_id as GENERATED BY DEFAULT AS IDENTITY,
# we *can* insert explicit verb_family_id values from the CSV when recreating the DB.

import pandas as pd
import sqlalchemy as sa
from sqlalchemy.dialects.postgresql import insert

# 1) Collect unique, non-null verb_family_id values from the CSV-derived dataframe
family_ids = (
    verbs_to_insert["verb_family_id"]
    .dropna()
    .astype(int)
    .drop_duplicates()
    .sort_values()
)

verb_family_seed = pd.DataFrame({
    "verb_family_id": family_ids,
    "family_code": [None] * len(family_ids), 
})

# 2) Pull existing IDs from DB so we only insert missing ones
existing_ids = pd.read_sql("SELECT verb_family_id FROM verb_family;", engine)["verb_family_id"].tolist()
existing_ids = set(int(x) for x in existing_ids)

to_insert = verb_family_seed[~verb_family_seed["verb_family_id"].isin(existing_ids)].copy()
print(f"verb_family already in DB: {len(existing_ids)}")
print(f"verb_family new to insert: {len(to_insert)}")

# 3) Insert missing rows (ON CONFLICT DO NOTHING)
meta = sa.MetaData()
verb_family_tbl = sa.Table("verb_family", meta, autoload_with=engine)

if not to_insert.empty:
    with engine.begin() as conn:
        rows = to_insert.to_dict(orient="records")
        stmt = insert(verb_family_tbl).values(rows).on_conflict_do_nothing(
            index_elements=["verb_family_id"]
        )
        conn.execute(stmt)
# Out:
# verb_family already in DB: 601
# verb_family new to insert: 0

# %%
import sqlalchemy as sa
from sqlalchemy.dialects.postgresql import insert

# ---- 1) Reflect the verb table from the DB ----
meta = sa.MetaData()
verb_tbl = sa.Table("verb", meta, autoload_with=engine)

def insert_ignore_duplicates(table, conn, keys, data_iter):
    """
    Pandas to_sql 'method' callable:
    UPSERT rows into verb. On conflict (dialect_id, infinitive), UPDATE columns
    so previously-inserted rows get their verb_family_id filled in.
    """
    rows = [dict(zip(keys, row)) for row in data_iter]
    if not rows:
        return 0

    stmt = insert(verb_tbl).values(rows)

    # Only update columns that exist in the DB table AND are present in the incoming rows
    incoming_cols = set(rows[0].keys())
    db_cols = set(verb_tbl.columns.keys())

    desired_updates = {
        "verb_family_id",
        "verb_category_id",
        "present_3sg",
        "meaning_english",
        "meaning_turkish",
        "requires_marker",
        "has_optional_prefix_ko",
        "has_optional_prefix_do",    }

    update_cols = sorted(list(desired_updates & incoming_cols & db_cols))

    if not update_cols:
        stmt = stmt.on_conflict_do_nothing(index_elements=["dialect_id", "infinitive"])
    else:
        stmt = stmt.on_conflict_do_update(
            index_elements=["dialect_id", "infinitive"],
            set_={c: getattr(stmt.excluded, c) for c in update_cols},
        )

    result = conn.execute(stmt)
    return result.rowcount


# ---- 2) Ensure verbs_to_insert exists (build it if missing) ----
if "verbs_to_insert" not in globals():
    if "verbs_clean" not in globals():
        raise NameError("verbs_clean is not defined yet. Run the cell that creates verbs_clean before inserting.")
    verbs_to_insert = (
        verbs_clean[[
            "verb_family_id",
            "verb_category_id",
            "dialect_id",
            "infinitive",
            "present_3sg",
            "meaning_english",
            "meaning_turkish",
        ]]
        .drop_duplicates()
        .copy()
    )

# ---- 3) Add defaults for DB columns that aren't in the CSV ----
# (we only add them if they exist in the DB table)
db_cols = [c.name for c in verb_tbl.columns]

for col in ["requires_marker",
            "has_optional_prefix_ko", "has_optional_prefix_do"]:
    if col in db_cols and col not in verbs_to_insert.columns:
        verbs_to_insert[col] = False

# ---- 4) Drop extra columns not present in the DB ----
extra = [c for c in verbs_to_insert.columns if c not in db_cols]
if extra:
    print("Dropping columns not in DB verb table:", extra)
    verbs_to_insert = verbs_to_insert.drop(columns=extra)

# ---- 5) Deduplicate on the conflict target and insert ----
verbs_to_insert = verbs_to_insert.drop_duplicates(subset=["dialect_id", "infinitive"]).copy()

with engine.begin() as conn:
    verbs_to_insert.to_sql(
        "verb",
        con=conn,
        if_exists="append",
        index=False,
        method=insert_ignore_duplicates,
        chunksize=1000,
    )

pd.read_sql("SELECT COUNT(*) AS n_verbs FROM verb;", engine)
# Out:
#    n_verbs
# 0      653

# %%
# --- Insert into verb, skipping duplicates safely ---
# Goal: align DataFrame columns to the actual DB table columns before to_sql()

# 1) Pull the true DB schema for the verb table
verb_cols = pd.read_sql("""
SELECT column_name
FROM information_schema.columns
WHERE table_schema = 'public' AND table_name = 'verb'
ORDER BY ordinal_position;
""", engine)["column_name"].tolist()

df = verbs_to_insert.copy()

# 2) Add defaults for columns that exist in SQL but not in the CSV/DataFrame
# (This handles optional-column defaults automatically.)
defaults_false = [
    "requires_marker",
    "has_optional_prefix_ko",
    "has_optional_prefix_do",]

for col in defaults_false:
    if col in verb_cols and col not in df.columns:
        df[col] = False

# If your table has other nullable columns you want to set explicitly, do it here.
# Example:
# if "notes" in verb_cols and "notes" not in df.columns:
#     df["notes"] = None

# 3) Drop any DataFrame columns that are NOT in the SQL table
extra = [c for c in df.columns if c not in verb_cols]
if extra:
    print("Dropping columns not in DB table:", extra)
    df = df.drop(columns=extra)

# 4) Reorder columns to match the table (optional but keeps things tidy)
df = df[[c for c in verb_cols if c in df.columns]]

# 5) Insert
with engine.begin() as conn:
    df.to_sql(
        "verb",
        con=conn,
        if_exists="append",
        index=False,
        method=insert_ignore_duplicates,
        chunksize=1000,
    )

pd.read_sql("SELECT COUNT(*) AS n_verbs FROM verb;", engine)
# Out:
#    n_verbs
# 0      653

# %%
# --- sanity sample: did inserts land the way we expect? ---
pd.read_sql("""
SELECT dialect_id, infinitive, present_3sg, verb_category_id
FROM verb
ORDER BY verb_id DESC
LIMIT 20;
""", engine)
# Out:
#     dialect_id     infinitive      present_3sg  verb_category_id
# 0            1        cexvamu        cuxvamams                 2
# 1            2        cexvamu        cuxvamams                 2
# 2            3        gexvamu       gyuxvamams                 2
# 3            4        zop̌ini          zop̌ons                 2
# 4            3        zop̌ini          zop̌ons                 2
# 5            1   yoxo cedvalu      yoxo codums                 2
# 6            2   yoxo cedvalu      yoxo codums                 2
# 7            4        yeç̌opu        yeç̌opups                 2
# 8            4  xe oǩotvaʒinu  xe oǩotvaʒinaps                 2
# 9            2   xe oǩoç̌apxu   xe oǩoç̌apxams                 2
# 10           1   xe oǩoç̌apxu   xe oǩoç̌apxams                 2
# 11           3   xe oǩoç̌apxu   xe oǩoç̌apxams                 2
# 12           3         uyonun           uyonun                 3
# 13           1         uyonun           uyonun                 3
# 14           2         uyonun           uyonun                 3
# 15           4          uqoun            uqoun                 3
# 16           4           unon             unon                 3
# 17           3           unon             unon                 3
# 18           4           uğun             uğun                 3
# 19           3           uğun             uğun                 3

# %%
# --- Post-import checks ---

# How many rows did we insert?
pd.read_sql("SELECT COUNT(*) AS n_verbs FROM verb;", engine)
# Out:
#    n_verbs
# 0      653

# %%
# Check for duplicates on your natural key (dialect_id, infinitive)
pd.read_sql("""
SELECT dialect_id, infinitive, COUNT(*) AS n
FROM verb
GROUP BY dialect_id, infinitive
HAVING COUNT(*) > 1
ORDER BY n DESC, dialect_id, infinitive
LIMIT 50;
""", engine)
# Out:
# Empty DataFrame
# Columns: [dialect_id, infinitive, n]
# Index: []

# %%
# Quick spot-check: sample rows
pd.read_sql("""
SELECT v.verb_id,
       v.verb_family_id,
       d.english_name AS dialect,
       vc.english_name AS category,
       v.infinitive,
       v.present_3sg,
       v.meaning_english,
       v.meaning_turkish
FROM verb v
JOIN dialect d ON d.dialect_id = v.dialect_id
JOIN verb_category vc ON vc.verb_category_id = v.verb_category_id
ORDER BY v.verb_id DESC
LIMIT 25;
""", engine)
# Out:
#     verb_id  verb_family_id          dialect         category     infinitive  \
# 0       692             210          Ardeşen    Ergative verb        cexvamu
# 1       691             210            Pazar    Ergative verb        cexvamu
# 2       690             210  Fındıklı/Arhavi    Ergative verb        gexvamu
# 3       689              38             Hopa    Ergative verb        zop̌ini
# 4       688              38  Fındıklı/Arhavi    Ergative verb        zop̌ini
# 5       687              38          Ardeşen    Ergative verb   yoxo cedvalu
# 6       686              38            Pazar    Ergative verb   yoxo cedvalu
# 7       685             125             Hopa    Ergative verb        yeç̌opu
# 8       684             130             Hopa    Ergative verb  xe oǩotvaʒinu
# 9       683              34            Pazar    Ergative verb   xe oǩoç̌apxu
# 10      682              34          Ardeşen    Ergative verb   xe oǩoç̌apxu
# 11      681              34  Fındıklı/Arhavi    Ergative verb   xe oǩoç̌apxu
# 12      680               6  Fındıklı/Arhavi      Dative verb         uyonun
# 13      679               6          Ardeşen      Dative verb         uyonun
# 14      678               6            Pazar      Dative verb         uyonun
# 15      677               6             Hopa      Dative verb          uqoun
# 16      676              95             Hopa      Dative verb           unon
# 17      675              95  Fındıklı/Arhavi      Dative verb           unon
# 18      674              95             Hopa      Dative verb           uğun
# 19      673              95  Fındıklı/Arhavi      Dative verb           uğun
# 20      672              95          Ardeşen      Dative verb           uğun
# 21      671              95            Pazar      Dative verb           uğun
# 22      670             203             Hopa  Nominative verb            ren
# 23      669             203  Fındıklı/Arhavi  Nominative verb            ren
# 24      668              95  Fındıklı/Arhavi    Ergative verb         oʒxunu
#
#         present_3sg                   meaning_english meaning_turkish
# 0         cuxvamams                      to celebrate        kutlamak
# 1         cuxvamams                      to celebrate        kutlamak
# 2        gyuxvamams                      to celebrate        kutlamak
# 3           zop̌ons         to mention, to talk about       bahsetmek
# 4           zop̌ons         to mention, to talk about       bahsetmek
# 5       yoxo codums         to name something/someone     adlandırmak
# 6       yoxo codums         to name something/someone     adlandırmak
# 7         yeç̌opups                            to buy           almak
# 8   xe oǩotvaʒinaps                        to applaud      alkışlamak
# 9    xe oǩoç̌apxams                        to applaud      alkışlamak
# 10   xe oǩoç̌apxams                        to applaud      alkışlamak
# 11   xe oǩoç̌apxams                        to applaud      alkışlamak
# 12           uyonun                           to have     var (canlı)
# 13           uyonun                           to have     var (canlı)
# 14           uyonun                           to have     var (canlı)
# 15            uqoun                           to have     var (canlı)
# 16             unon                           to want         istemek
# 17             unon                           to want         istemek
# 18             uğun                           to have    var (cansız)
# 19             uğun                           to have    var (cansız)
# 20             uğun                           to have    var (cansız)
# 21             uğun                           to have    var (cansız)
# 22              ren                             to be           olmak
# 23              ren                             to be           olmak
# 24          ʒxunums  to distinguish, to differentiate    ayrım yapmak

# %%
# Ensure all dialect_id/category_id mappings existed in the CSV
# (These should be empty if your earlier mapping diagnostics passed)
print("Unmapped dialect_id rows:", verbs[verbs["dialect_id"].isna()].shape[0])
print("Unmapped verb_category_id rows:", verbs[verbs["verb_category_id"].isna()].shape[0])
# Out:
# Unmapped dialect_id rows: 0
# Unmapped verb_category_id rows: 0

# %%
import pandas as pd

preverbs = [
    "ce","cela","ceşǩa","dolo","e","eşǩa",
    "me","mo", "gela", "ge",
    "meo","moo","mola","gola","moǩo",
    "ama","gama","eo","meşǩa","go","goo","koǯo","eǯa","eǩa",
    "oǩo","ǩoşǩa", "ela",
    "oxo","do", "ye",
]

preverb_df = pd.DataFrame({"spelling": preverbs}).drop_duplicates().sort_values("spelling")

# Optional: normalize whitespace
preverb_df["spelling"] = preverb_df["spelling"].str.strip()

preverb_df
# Out:
#    spelling
# 15      ama
# 0        ce
# 1      cela
# 2     ceşǩa
# 28       do
# 3      dolo
# 4         e
# 26      ela
# 17       eo
# 5      eşǩa
# 23      eǩa
# 22      eǯa
# 16     gama
# 9        ge
# 8      gela
# 19       go
# 13     gola
# 20      goo
# 21     koǯo
# 6        me
# 10      meo
# 18    meşǩa
# 7        mo
# 12     mola
# 11      moo
# 14     moǩo
# 27      oxo
# 24      oǩo
# 29       ye
# 25    ǩoşǩa

# %%
import pandas as pd

# --- Make sure we have a "spelling" column no matter what the source column is called ---

preverb_df_db = preverb_df.copy()

if "spelling" not in preverb_df_db.columns:
    if "code" in preverb_df_db.columns:
        preverb_df_db = preverb_df_db.rename(columns={"code": "spelling"})
    else:
        raise ValueError(f"Expected a 'code' or 'spelling' column, found: {list(preverb_df_db.columns)}")

# keep only the columns that exist in the SQL table
preverb_df_db = preverb_df_db[["spelling"]].copy()

# optional columns (table has them, so we can set them)
preverb_df_db["preverb_group"] = None
preverb_df_db["notes"] = None

# clean + normalize
preverb_df_db["spelling"] = (
    preverb_df_db["spelling"]
    .astype(str)
    .str.strip()
)

# drop blanks just in case
preverb_df_db = preverb_df_db[preverb_df_db["spelling"] != ""]

# dedupe + stable order
preverb_df_db = preverb_df_db.drop_duplicates(subset=["spelling"]).sort_values("spelling").reset_index(drop=True)

# 1) pull existing spellings from DB
existing = pd.read_sql("SELECT spelling FROM preverb;", engine)
existing_set = set(existing["spelling"].astype(str).str.strip())

# 2) keep only new spellings
to_insert = preverb_df_db[~preverb_df_db["spelling"].isin(existing_set)].copy()

print(f"Already in DB: {len(existing_set)}")
print(f"New to insert: {len(to_insert)}")

# 3) insert only new ones
if not to_insert.empty:
    with engine.begin() as conn:
        to_insert.to_sql(
            "preverb",
            con=conn,
            if_exists="append",
            index=False,
            chunksize=1000,
        )

pd.read_sql("""
SELECT preverb_id, spelling, preverb_group, notes
FROM preverb
ORDER BY spelling;
""", engine)
# Out:
# Already in DB: 30
# New to insert: 0
#     preverb_id spelling preverb_group notes
# 0            1      ama          None  None
# 1            2       ce          None  None
# 2            3     cela          None  None
# 3            4    ceşǩa          None  None
# 4            5       do          None  None
# 5            6     dolo          None  None
# 6            7        e          None  None
# 7           11      eǩa          None  None
# 8            8      ela          None  None
# 9            9       eo          None  None
# 10          10     eşǩa          None  None
# 11          12      eǯa          None  None
# 12          13     gama          None  None
# 13          14       ge          None  None
# 14          15     gela          None  None
# 15          16       go          None  None
# 16          17     gola          None  None
# 17          18      goo          None  None
# 18          29    ǩoşǩa          None  None
# 19          19     koǯo          None  None
# 20          20       me          None  None
# 21          21      meo          None  None
# 22          22    meşǩa          None  None
# 23          23       mo          None  None
# 24          26     moǩo          None  None
# 25          24     mola          None  None
# 26          25      moo          None  None
# 27          28      oǩo          None  None
# 28          27      oxo          None  None
# 29          42       ye          None  None

# %%
pd.read_sql("SELECT preverb_id, spelling, preverb_group, notes FROM preverb ORDER BY spelling;", engine)
# Out:
#     preverb_id spelling preverb_group notes
# 0            1      ama          None  None
# 1            2       ce          None  None
# 2            3     cela          None  None
# 3            4    ceşǩa          None  None
# 4            5       do          None  None
# 5            6     dolo          None  None
# 6            7        e          None  None
# 7           11      eǩa          None  None
# 8            8      ela          None  None
# 9            9       eo          None  None
# 10          10     eşǩa          None  None
# 11          12      eǯa          None  None
# 12          13     gama          None  None
# 13          14       ge          None  None
# 14          15     gela          None  None
# 15          16       go          None  None
# 16          17     gola          None  None
# 17          18      goo          None  None
# 18          29    ǩoşǩa          None  None
# 19          19     koǯo          None  None
# 20          20       me          None  None
# 21          21      meo          None  None
# 22          22    meşǩa          None  None
# 23          23       mo          None  None
# 24          26     moǩo          None  None
# 25          24     mola          None  None
# 26          25      moo          None  None
# 27          28      oǩo          None  None
# 28          27      oxo          None  None
# 29          42       ye          None  None

# %%
print("rows in verbs_to_insert:", len(verbs_to_insert))
print("nonnull verb_family_id in df:", verbs_to_insert["verb_family_id"].notna().sum())
# Out:
# rows in verbs_to_insert: 653
# nonnull verb_family_id in df: 653

# %%
# double checking to see which df to use for conjugation csv:
import pandas as pd

items = list(globals().items())
dfs = [(name, obj) for name, obj in items if isinstance(obj, pd.DataFrame)]

def looks_relevant(df: pd.DataFrame) -> bool:
    cols = " ".join(map(str, df.columns)).lower()
    return ("infinit" in cols) or ("laz" in cols) or ("verb" in cols) or ("region" in cols)

for name, df in dfs:
    if looks_relevant(df):
        print("\n" + "="*80)
        print(name)
        print("Shape:", df.shape)
        print("Columns:", list(df.columns))
        display(df.head(3))
# Out:
# ================================================================================
# _
# Shape: (30, 4)
# Columns: ['preverb_id', 'spelling', 'preverb_group', 'notes']
#    preverb_id spelling preverb_group notes
# 0           1      ama          None  None
# 1           2       ce          None  None
# 2           3     cela          None  None
# ================================================================================
# __
# Shape: (30, 4)
# Columns: ['preverb_id', 'spelling', 'preverb_group', 'notes']
#    preverb_id spelling preverb_group notes
# 0           1      ama          None  None
# 1           2       ce          None  None
# 2           3     cela          None  None
# ================================================================================
# raw
# Shape: (327, 11)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'Region', 'Laz 3rd Person Singular Present Alternative 1', 'Region Alternative 1', 'Laz 3rd Person Singular Present Alternative 2', 'Region Alternative 2', 'English Translation', 'Turkish Verb', 'verb_family_id']
#   Laz Infinitive Category Laz 3rd Person Singular Present          Region  \
# 0  avara doskudu      TVM                  avara doskudun  PZ, AŞ, FA, HO
# 1        cebazgu      TVE                       cobazgams          PZ, AŞ
# 2        cebgaru      TVE                         cabgars              PZ
#
#   Laz 3rd Person Singular Present Alternative 1 Region Alternative 1  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
#
#   Laz 3rd Person Singular Present Alternative 2 Region Alternative 2  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
#
#               English Translation  Turkish Verb  verb_family_id
# 0                      to be idle  avare kalmak              19
# 1  to press, to step on something        basmak             139
# 2        to lament over something   ağıt yakmak             108
# ================================================================================
# df
# Shape: (653, 8)
# Columns: ['verb_family_id', 'dialect_id', 'verb_category_id', 'infinitive', 'present_3sg', 'meaning_english', 'meaning_turkish', 'requires_marker']
#    verb_family_id  dialect_id  verb_category_id     infinitive  \
# 0              19           2                 1  avara doskudu
# 0              19           1                 1  avara doskudu
# 0              19           3                 1  avara doskudu
#
#       present_3sg meaning_english meaning_turkish  requires_marker
# 0  avara doskudun      to be idle    avare kalmak            False
# 0  avara doskudun      to be idle    avare kalmak            False
# 0  avara doskudun      to be idle    avare kalmak            False
# ================================================================================
# _5
# Shape: (5, 11)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'Region', 'Laz 3rd Person Singular Present Alternative 1', 'Region Alternative 1', 'Laz 3rd Person Singular Present Alternative 2', 'Region Alternative 2', 'English Translation', 'Turkish Verb', 'verb_family_id']
#   Laz Infinitive Category Laz 3rd Person Singular Present          Region  \
# 0  avara doskudu      TVM                  avara doskudun  PZ, AŞ, FA, HO
# 1        cebazgu      TVE                       cobazgams          PZ, AŞ
# 2        cebgaru      TVE                         cabgars              PZ
#
#   Laz 3rd Person Singular Present Alternative 1 Region Alternative 1  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
#
#   Laz 3rd Person Singular Present Alternative 2 Region Alternative 2  \
# 0                                           NaN                  NaN
# 1                                           NaN                  NaN
# 2                                           NaN                  NaN
#
#               English Translation  Turkish Verb  verb_family_id
# 0                      to be idle  avare kalmak              19
# 1  to press, to step on something        basmak             139
# 2        to lament over something   ağıt yakmak             108
# ================================================================================
# _9
# Shape: (108, 4)
# Columns: ['verb_category_id', 'english_name', 'turkish_name', 'code']
#    verb_category_id     english_name     turkish_name code
# 0                 1  Nominative verb  Nominatif fiili  TVM
# 1                 2    Ergative verb    Ergatif fiili  TVE
# 2                 3      Dative verb    Yönelme fiili  IVD
# ================================================================================
# cat_map
# Shape: (108, 2)
# Columns: ['verb_category_id', 'code']
#    verb_category_id code
# 0                 1  TVM
# 1                 2  TVE
# 2                 3  IVD
# ================================================================================
# _10
# Shape: (108, 2)
# Columns: ['verb_category_id', 'code']
#    verb_category_id code
# 0                 1  TVM
# 1                 2  TVE
# 2                 3  IVD
# ================================================================================
# verbs
# Shape: (25020, 17)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'English Translation', 'Turkish Verb', 'Region', 'verb_family_id', 'preverb_family', 'infinitive', 'code', 'present_3sg', 'meaning_english', 'meaning_turkish', 'region', 'verb_category_id', 'region_code', 'dialect_id']
#   Laz Infinitive Category Laz 3rd Person Singular Present English Translation  \
# 0  avara doskudu      TVM                  avara doskudun          to be idle
# 0  avara doskudu      TVM                  avara doskudun          to be idle
# 0  avara doskudu      TVM                  avara doskudun          to be idle
#
#    Turkish Verb          Region  verb_family_id preverb_family     infinitive  \
# 0  avare kalmak  PZ, AŞ, FA, HO              19           <NA>  avara doskudu
# 0  avare kalmak  PZ, AŞ, FA, HO              19           <NA>  avara doskudu
# 0  avare kalmak  PZ, AŞ, FA, HO              19           <NA>  avara doskudu
#
#   code     present_3sg meaning_english meaning_turkish          region  \
# 0  TVM  avara doskudun      to be idle    avare kalmak  PZ, AŞ, FA, HO
# 0  TVM  avara doskudun      to be idle    avare kalmak  PZ, AŞ, FA, HO
# 0  TVM  avara doskudun      to be idle    avare kalmak  PZ, AŞ, FA, HO
#
#    verb_category_id region_code  dialect_id
# 0                 1          PZ           2
# 0                 1          AŞ           1
# 0                 1          FA           3
# ================================================================================
# bad
# Shape: (0, 2)
# Columns: ['region', 'region_code']
# Empty DataFrame
# Columns: [region, region_code]
# Index: []
# ================================================================================
# _11
# Shape: (0, 2)
# Columns: ['infinitive', 'code']
# Empty DataFrame
# Columns: [infinitive, code]
# Index: []
# ================================================================================
# dialects
# Shape: (4, 3)
# Columns: ['english_name', 'turkish_name', 'laz_name']
#       english_name     turkish_name     laz_name
# 0          Ardeşen          Ardeşen    Art̆aşeni
# 1            Pazar            Pazar        Atina
# 2  Fındıklı/Arhavi  Fındıklı/Arhavi  Viǯe/Arkabi
# ================================================================================
# _12
# Shape: (4, 3)
# Columns: ['english_name', 'turkish_name', 'laz_name']
#       english_name     turkish_name     laz_name
# 0          Ardeşen          Ardeşen    Art̆aşeni
# 1            Pazar            Pazar        Atina
# 2  Fındıklı/Arhavi  Fındıklı/Arhavi  Viǯe/Arkabi
# ================================================================================
# dialects_new
# Shape: (0, 3)
# Columns: ['english_name', 'turkish_name', 'laz_name']
# Empty DataFrame
# Columns: [english_name, turkish_name, laz_name]
# Index: []
# ================================================================================
# _13
# Shape: (0, 3)
# Columns: ['english_name', 'turkish_name', 'laz_name']
# Empty DataFrame
# Columns: [english_name, turkish_name, laz_name]
# Index: []
# ================================================================================
# _16
# Shape: (4, 4)
# Columns: ['dialect_id', 'english_name', 'turkish_name', 'laz_name']
#    dialect_id     english_name     turkish_name     laz_name
# 0           1          Ardeşen          Ardeşen    Art̆aşeni
# 1           2            Pazar            Pazar        Atina
# 2           3  Fındıklı/Arhavi  Fındıklı/Arhavi  Viǯe/Arkabi
# ================================================================================
# _18
# Shape: (0, 5)
# Columns: ['Laz Infinitive', 'Category', 'infinitive', 'code', 'verb_category_id']
# Empty DataFrame
# Columns: [Laz Infinitive, Category, infinitive, code, verb_category_id]
# Index: []
# ================================================================================
# missing
# Shape: (0, 11)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'English Translation', 'Turkish Verb', 'infinitive', 'code', 'present_3sg', 'meaning_english', 'meaning_turkish', 'verb_category_id']
# Empty DataFrame
# Columns: [Laz Infinitive, Category, Laz 3rd Person Singular Present, English Translation, Turkish Verb, infinitive, code, present_3sg, meaning_english, meaning_turkish, verb_category_id]
# Index: []
# ================================================================================
# _20
# Shape: (0, 11)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'English Translation', 'Turkish Verb', 'infinitive', 'code', 'present_3sg', 'meaning_english', 'meaning_turkish', 'verb_category_id']
# Empty DataFrame
# Columns: [Laz Infinitive, Category, Laz 3rd Person Singular Present, English Translation, Turkish Verb, infinitive, code, present_3sg, meaning_english, meaning_turkish, verb_category_id]
# Index: []
# ================================================================================
# _21
# Shape: (1, 1)
# Columns: ['n_verbs']
#    n_verbs
# 0      653
# ================================================================================
# _23
# Shape: (10, 6)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'English Translation', 'Turkish Verb', 'Region']
#   Laz Infinitive Category Laz 3rd Person Singular Present  \
# 0  avara doskudu      TVM                  avara doskudun
# 1        cebazgu      TVE                       cobazgams
# 2        cebgaru      TVE                         cabgars
#
#               English Translation  Turkish Verb          Region
# 0                      to be idle  avare kalmak  PZ, AŞ, FA, HO
# 1  to press, to step on something        basmak          PZ, AŞ
# 2        to lament over something   ağıt yakmak              PZ
# ================================================================================
# usable
# Shape: (327, 12)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'English Translation', 'Turkish Verb', 'Region', 'infinitive', 'code', 'present_3sg', 'meaning_english', 'meaning_turkish', 'region']
#   Laz Infinitive Category Laz 3rd Person Singular Present  \
# 0  avara doskudu      TVM                  avara doskudun
# 1        cebazgu      TVE                       cobazgams
# 2        cebgaru      TVE                         cabgars
#
#               English Translation  Turkish Verb          Region  \
# 0                      to be idle  avare kalmak  PZ, AŞ, FA, HO
# 1  to press, to step on something        basmak          PZ, AŞ
# 2        to lament over something   ağıt yakmak              PZ
#
#       infinitive code     present_3sg                 meaning_english  \
# 0  avara doskudu  TVM  avara doskudun                      to be idle
# 1        cebazgu  TVE       cobazgams  to press, to step on something
# 2        cebgaru  TVE         cabgars        to lament over something
#
#   meaning_turkish          region
# 0    avare kalmak  PZ, AŞ, FA, HO
# 1          basmak          PZ, AŞ
# 2     ağıt yakmak              PZ
# ================================================================================
# _28
# Shape: (0, 2)
# Columns: ['region', 'region_code']
# Empty DataFrame
# Columns: [region, region_code]
# Index: []
# ================================================================================
# base
# Shape: (25020, 17)
# Columns: ['Laz Infinitive', 'Category', 'Laz 3rd Person Singular Present', 'English Translation', 'Turkish Verb', 'Region', 'verb_family_id', 'preverb_family', 'infinitive', 'code', 'present_3sg', 'meaning_english', 'meaning_turkish', 'region', 'verb_category_id', 'region_code', 'dialect_id']
#   Laz Infinitive Category Laz 3rd Person Singular Present English Translation  \
# 0  avara doskudu      TVM                  avara doskudun          to be idle
# 0  avara doskudu      TVM                  avara doskudun          to be idle
# 0  avara doskudu      TVM                  avara doskudun          to be idle
#
#    Turkish Verb          Region  verb_family_id preverb_family     infinitive  \
# 0  avare kalmak  PZ, AŞ, FA, HO              19           <NA>  avara doskudu
# 0  avare kalmak  PZ, AŞ, FA, HO              19           <NA>  avara doskudu
# 0  avare kalmak  PZ, AŞ, FA, HO              19           <NA>  avara doskudu
#
#   code     present_3sg meaning_english meaning_turkish          region  \
# 0  TVM  avara doskudun      to be idle    avare kalmak  PZ, AŞ, FA, HO
# 0  TVM  avara doskudun      to be idle    avare kalmak  PZ, AŞ, FA, HO
# 0  TVM  avara doskudun      to be idle    avare kalmak  PZ, AŞ, FA, HO
#
#    verb_category_id region_code  dialect_id
# 0                 1          PZ           2
# 0                 1          AŞ           1
# 0                 1          FA           3
# ================================================================================
# verbs_to_insert
# Shape: (653, 8)
# Columns: ['verb_family_id', 'verb_category_id', 'dialect_id', 'infinitive', 'present_3sg', 'meaning_english', 'meaning_turkish', 'requires_marker']
#    verb_family_id  verb_category_id  dialect_id     infinitive  \
# 0              19                 1           2  avara doskudu
# 0              19                 1           1  avara doskudu
# 0              19                 1           3  avara doskudu
#
#       present_3sg meaning_english meaning_turkish  requires_marker
# 0  avara doskudun      to be idle    avare kalmak            False
# 0  avara doskudun      to be idle    avare kalmak            False
# 0  avara doskudun      to be idle    avare kalmak            False
# ================================================================================
# _29
# Shape: (5, 8)
# Columns: ['verb_family_id', 'verb_category_id', 'dialect_id', 'infinitive', 'present_3sg', 'meaning_english', 'meaning_turkish', 'requires_marker']
#    verb_family_id  verb_category_id  dialect_id     infinitive  \
# 0              19                 1           2  avara doskudu
# 0              19                 1           1  avara doskudu
# 0              19                 1           3  avara doskudu
#
#       present_3sg meaning_english meaning_turkish  requires_marker
# 0  avara doskudun      to be idle    avare kalmak            False
# 0  avara doskudun      to be idle    avare kalmak            False
# 0  avara doskudun      to be idle    avare kalmak            False
# ================================================================================
# verb_family_seed
# Shape: (205, 2)
# Columns: ['verb_family_id', 'family_code']
#       verb_family_id family_code
# 2160               1        None
# 9324               2        None
# 5112               3        None
# ================================================================================
# to_insert
# Shape: (0, 3)
# Columns: ['spelling', 'preverb_group', 'notes']
# Empty DataFrame
# Columns: [spelling, preverb_group, notes]
# Index: []
# ================================================================================
# _31
# Shape: (1, 1)
# Columns: ['n_verbs']
#    n_verbs
# 0      653
# ================================================================================
# _32
# Shape: (1, 1)
# Columns: ['n_verbs']
#    n_verbs
# 0      653
# ================================================================================
# _33
# Shape: (20, 4)
# Columns: ['dialect_id', 'infinitive', 'present_3sg', 'verb_category_id']
#    dialect_id infinitive present_3sg  verb_category_id
# 0           1    cexvamu   cuxvamams                 2
# 1           2    cexvamu   cuxvamams                 2
# 2           3    gexvamu  gyuxvamams                 2
# ================================================================================
# _34
# Shape: (1, 1)
# Columns: ['n_verbs']
#    n_verbs
# 0      653
# ================================================================================
# _35
# Shape: (0, 3)
# Columns: ['dialect_id', 'infinitive', 'n']
# Empty DataFrame
# Columns: [dialect_id, infinitive, n]
# Index: []
# ================================================================================
# _36
# Shape: (25, 8)
# Columns: ['verb_id', 'verb_family_id', 'dialect', 'category', 'infinitive', 'present_3sg', 'meaning_english', 'meaning_turkish']
#    verb_id  verb_family_id          dialect       category infinitive  \
# 0      692             210          Ardeşen  Ergative verb    cexvamu
# 1      691             210            Pazar  Ergative verb    cexvamu
# 2      690             210  Fındıklı/Arhavi  Ergative verb    gexvamu
#
#   present_3sg meaning_english meaning_turkish
# 0   cuxvamams    to celebrate        kutlamak
# 1   cuxvamams    to celebrate        kutlamak
# 2  gyuxvamams    to celebrate        kutlamak
# ================================================================================
# preverb_df_db
# Shape: (30, 3)
# Columns: ['spelling', 'preverb_group', 'notes']
#   spelling preverb_group notes
# 0      ama          None  None
# 1       ce          None  None
# 2     cela          None  None
# ================================================================================
# _39
# Shape: (30, 4)
# Columns: ['preverb_id', 'spelling', 'preverb_group', 'notes']
#    preverb_id spelling preverb_group notes
# 0           1      ama          None  None
# 1           2       ce          None  None
# 2           3     cela          None  None
# ================================================================================
# _40
# Shape: (30, 4)
# Columns: ['preverb_id', 'spelling', 'preverb_group', 'notes']
#    preverb_id spelling preverb_group notes
# 0           1      ama          None  None
# 1           2       ce          None  None
# 2           3     cela          None  None

# %%
import os, sys, importlib
from pathlib import Path
import pandas as pd

# -----------------------------
# CONFIG
# -----------------------------
BACKEND_DIR = Path(r"C:\Users\Adam\Lazverbcon\laz_verb_conjugator\backend")
OUT_PATH    = Path(r"C:\Users\Adam\Lazverbcon\laz_verb_conjugator\SQL Lazverbcon\verb_form_seed_stage.csv")

assert BACKEND_DIR.exists(), BACKEND_DIR

# Ensure backend import + relative paths work
os.chdir(BACKEND_DIR)
sys.path.insert(0, str(BACKEND_DIR))

from conjugation import conjugate_verb

# Load tense modules
tense_modules = {
    "ivd_present": importlib.import_module("notebooks.ivd_present"),
    "ivd_past": importlib.import_module("notebooks.ivd_past"),
    "ivd_pastpro": importlib.import_module("notebooks.ivd_pastpro"),
    "ivd_future": importlib.import_module("notebooks.ivd_future"),
    "tvm_tve_presentperf": importlib.import_module("notebooks.tvm_tve_presentperf"),
    "tvm_tve_potential": importlib.import_module("notebooks.tvm_tve_potential"),
    "tvm_tve_passive": importlib.import_module("notebooks.tvm_tve_passive"),
    "tvm_tense": importlib.import_module("notebooks.tvm_tense"),
    "tve_present": importlib.import_module("notebooks.tve_present"),
    "tve_pastpro": importlib.import_module("notebooks.tve_pastpro"),
    "tve_past": importlib.import_module("notebooks.tve_past"),
    "tve_future": importlib.import_module("notebooks.tve_future"),
}

PRONOUN_TO_SUBJECT = {
    "ma": "S1SG", "si": "S2SG",
    "him": "S3SG", "himus": "S3SG", "himuk": "S3SG",
    "heya": "S3SG", "heyas": "S3SG", "heyak": "S3SG",
    "(h)em": "S3SG", "(h)emus": "S3SG", "(h)emuk": "S3SG",
    "şǩu": "S1PL", "çku": "S1PL", "çkin": "S1PL",
    "t̆ǩva": "S2PL", "tkva": "S2PL", "tkvan": "S2PL",
    "hini": "S3PL", "hinis": "S3PL", "hinik": "S3PL",
    "hentepe": "S3PL", "hentepes": "S3PL", "hentepek": "S3PL",
    "entepe": "S3PL", "entepes": "S3PL", "entepek": "S3PL",
}
PRONOUN_TO_OBJECT = {
    "ma": "O1SG", "si": "O2SG",
    "him": "O3SG", "himus": "O3SG", "himuk": "O3SG",
    "heya": "O3SG", "heyas": "O3SG", "heyak": "O3SG",
    "(h)em": "O3SG", "(h)emus": "O3SG", "(h)emuk": "O3SG",
    "şǩu": "O1PL", "çku": "O1PL", "çkin": "O1PL",
    "t̆ǩva": "O2PL", "tkva": "O2PL", "tkvan": "O2PL",
    "hini": "O3PL", "hinis": "O3PL", "hinik": "O3PL",
    "hentepe": "O3PL", "hentepes": "O3PL", "hentepek": "O3PL",
    "entepe": "O3PL", "entepes": "O3PL", "entepek": "O3PL",
}

DB_TO_BACKEND_TENSE = {
    "present": "present",
    "past": "past",
    "future": "future",
    "present_perfect": "presentperf",
    "past_progressive": "pastpro",
}
DB_TENSES = ["present", "past", "future", "present_perfect", "past_progressive"]

# -----------------------------
# DERIVATION (DB) -> ASPECT (backend arg)
# -----------------------------
DERIVATIONS = ["none", "passive", "potential"]
DERIVATION_TO_ASPECT = {
    "none": None,
    "passive": "passive",
    "potential": "potential",
}

# -----------------------------
# SOURCE: notebook df
# -----------------------------
if "verbs_to_insert" not in globals():
    raise NameError("verbs_to_insert not found in notebook globals().")

df_src = verbs_to_insert.copy()
df_src["infinitive"] = df_src["infinitive"].astype(str).str.strip()

infinitives = sorted(df_src["infinitive"].unique())
print("Unique infinitives:", len(infinitives), "example:", infinitives[:10])

# -----------------------------
# GENERATE
# -----------------------------
rows = []
n_errors = 0
n_obj_fallbacks = 0
n_deriv_skips = 0

for i, infinitive in enumerate(infinitives, 1):
    for db_tense in DB_TENSES:
        backend_tense = DB_TO_BACKEND_TENSE[db_tense]

        for derivation in DERIVATIONS:
            # DB constraint: present_perfect only allows derivation='none' and object NULL
            if db_tense == "present_perfect" and derivation != "none":
                continue

            aspect = DERIVATION_TO_ASPECT[derivation]

            # DB constraint: if derivation != 'none', object must be NULL
            # Also present_perfect must have object NULL
            if derivation != "none" or db_tense == "present_perfect":
                preferred_obj = None
            else:
                preferred_obj = "all"

            # Run conjugator, with object fallback only when it's the known "cannot take object" case
            try:
                out = conjugate_verb(
                    tense_modules=tense_modules,
                    infinitive=infinitive,
                    tense=backend_tense,
                    aspect=aspect,
                    obj=preferred_obj,
                    subject="all",
                    optative=False,
                    imperative=False,
                    neg_imperative=False,
                    applicative=False,
                    causative=False,
                    simple_causative=False,
                )
            except ValueError as e:
                msg = str(e)

                # object not allowed -> retry subject-only (ONLY when we asked for objects)
                if preferred_obj is not None and (("cannot take an object" in msg) or ("nesne alamaz" in msg)):
                    n_obj_fallbacks += 1
                    out = conjugate_verb(
                        tense_modules=tense_modules,
                        infinitive=infinitive,
                        tense=backend_tense,
                        aspect=aspect,
                        obj=None,
                        subject="all",
                        optative=False,
                        imperative=False,
                        neg_imperative=False,
                        applicative=False,
                        causative=False,
                        simple_causative=False,
                    )
                else:
                    # Derivation/aspect might not exist for some verbs/tense modules; count and skip
                    n_errors += 1
                    if n_errors <= 10:
                        print("VALUEERROR:", infinitive, db_tense, derivation, "|", msg)
                    n_deriv_skips += 1
                    continue

            res = out.get("result", None)

            if not isinstance(res, dict):
                n_errors += 1
                if n_errors <= 5:
                    print("NON-DICT result:", infinitive, db_tense, derivation, type(res), res)
                continue

            if "error" in res:
                n_errors += 1
                if n_errors <= 10:
                    print("ERROR:", infinitive, db_tense, derivation, res["error"])
                continue

            for dialect_code, frame_dict in res.items():
                if not isinstance(frame_dict, dict):
                    continue

                for frame, items in frame_dict.items():
                    if not isinstance(items, list):
                        continue

                    for it in items:
                        if not isinstance(it, dict):
                            continue

                        subj = (it.get("subject") or "").strip()
                        obj  = (it.get("object") or it.get("obj") or "").strip()

                        rows.append({
                            "dialect_code": dialect_code,
                            "frame": frame,

                            "subject": subj,
                            "object": obj,

                            "subject_code": PRONOUN_TO_SUBJECT.get(subj, None) if subj else None,
                            "object_code": PRONOUN_TO_OBJECT.get(obj, None) if obj else None,

                            "spelling": (it.get("conjugation") or "").strip(),

                            "infinitive": infinitive,
                            "tense": db_tense,
                            "derivation": derivation,
                            "mood": "indicative",
                            "is_applicative": False,
                            "is_causative": False,
                            "is_double_causative": False,
                            "optional_prefix": None,
                        })

    if i % 25 == 0:
        print(
            f"Processed {i}/{len(infinitives)} | rows: {len(rows)} | errors: {n_errors} "
            f"| obj fallbacks: {n_obj_fallbacks} | deriv skips: {n_deriv_skips}"
        )

df_out = pd.DataFrame(rows)

print("\nFINAL rows:", len(df_out))
print("Object fallbacks:", n_obj_fallbacks)
print("Derivation skips:", n_deriv_skips)
print("Non-empty object count:", (df_out["object"].fillna("").str.strip() != "").sum())

print("Writing to:", OUT_PATH.resolve())
df_out.to_csv(OUT_PATH, index=False)

print("Exists?", OUT_PATH.exists())
if OUT_PATH.exists():
    print("mtime:", pd.Timestamp(OUT_PATH.stat().st_mtime, unit="s"))
    print("File size (bytes):", OUT_PATH.stat().st_size)
    display(df_out.head(10))
# Out:
# Unique infinitives: 299 example: ['avara doskudu', 'cebazgu', 'cebgaru', 'cedginu', 'cegapu', 'ceginu', 'celabalu', 'cemp̌onu', 'cexunu', 'cexvamu']
# ERROR: avara doskudu present none Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# ERROR: avara doskudu past none Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# ERROR: avara doskudu future none Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# ERROR: avara doskudu past_progressive none Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: skud
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: bgar
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# ERROR: cedginu present passive Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# ERROR: cedginu present potential Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# ERROR: cedginu past passive Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# ERROR: cedginu past potential Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# ERROR: cedginu future passive Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# ERROR: cedginu future potential Verb exists in module lists, but no conjugation output was produced (likely missing/invalid parameters).
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: cadginen
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: labal
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: ç̌
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# root: bad
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bal
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: bazginap
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dgit
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: dvum
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# root: gur
# Processed 25/299 | rows: 7074 | errors: 91 | obj fallbacks: 4 | deriv skips: 0
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: gut
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: in
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: ç̌ar
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: mçin
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: skid
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# root: sǩud
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# preverb: do
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: tan
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: şǩval
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: ǩan
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# first letter: i
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: oçval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: xondval
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: qon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: yon
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: çam
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: ǩat̆
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: bažg
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gap
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: gin
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# root: ǩid
# Processed 50/299 | rows: 17646 | errors: 133 | obj fallbacks: 8 | deriv skips: 0
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mgar
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: mp̌on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: nt̆on
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xun
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: xvam
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ç̌ǩ
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩordin
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǩord
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯipx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: ǯopx
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: iloǩid
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: us
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: ndun
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: nǯǩ
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: xir
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: şin
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ǩuʒx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: ntx
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# root: umcu
# Processed 75/299 | rows: 25344 | errors: 215 | obj fallbacks: 8 | deriv skips: 0
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: bazg
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvapin
# root: mgvap
# root: mgvap
# root: mgvap
# root: mgvap
# root: mgvap
# root: mgvap
# ...
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ğmal
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǩri
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯam
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# root: ǯil
# Processed 275/299 | rows: 109066 | errors: 538 | obj fallbacks: 44 | deriv skips: 0
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯod
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯ
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯun
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩed
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩid
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩ
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ǯǩun
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒad
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: ʒxun
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: e
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌apx
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: dval
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: op̌in
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ç̌op
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: ǯal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
# root: dgal
#
# FINAL rows: 119506
# Object fallbacks: 44
# Derivation skips: 0
# Non-empty object count: 82960
# Writing to: C:\Users\Adam\Lazverbcon\laz_verb_conjugator\SQL Lazverbcon\verb_form_seed_stage.csv
# Exists? True
# mtime: 2026-03-03 02:32:22.476168394
# File size (bytes): 11860278
#   dialect_code       frame subject object subject_code object_code  \
# 0           PZ  Nominative      ma                S1SG        None
# 1           PZ  Nominative      si                S2SG        None
# 2           PZ  Nominative     him                S3SG        None
# 3           PZ  Nominative     şǩu                S1PL        None
# 4           PZ  Nominative   t̆ǩva                S2PL        None
# 5           PZ  Nominative    hini                S3PL        None
# 6           AŞ  Nominative      ma                S1SG        None
# 7           AŞ  Nominative      si                S2SG        None
# 8           AŞ  Nominative     him                S3SG        None
# 9           AŞ  Nominative     şǩu                S1PL        None
#
#             spelling     infinitive    tense derivation        mood  \
# 0   avara doviskuder  avara doskudu  present    passive  indicative
# 1     avara diskuder  avara doskudu  present    passive  indicative
# 2     avara diskuden  avara doskudu  present    passive  indicative
# 3  avara doviskudert  avara doskudu  present    passive  indicative
# 4    avara diskudert  avara doskudu  present    passive  indicative
# 5   avara diskudenan  avara doskudu  present    passive  indicative
# 6   avara doviskuder  avara doskudu  present    passive  indicative
# 7     avara diskuder  avara doskudu  present    passive  indicative
# 8     avara diskuden  avara doskudu  present    passive  indicative
# 9  avara doviskudert  avara doskudu  present    passive  indicative
#
#    is_applicative  is_causative  is_double_causative optional_prefix
# 0           False         False                False            None
# 1           False         False                False            None
# 2           False         False                False            None
# 3           False         False                False            None
# 4           False         False                False            None
# 5           False         False                False            None
# 6           False         False                False            None
# 7           False         False                False            None
# 8           False         False                False            None
# 9           False         False                False            None

# %%
print("Writing to:", OUT_PATH)
print("Exists?", OUT_PATH.exists())
print("Absolute path:", OUT_PATH.resolve())
print("Last modified:", pd.Timestamp(OUT_PATH.stat().st_mtime, unit="s"))
print("File size:", OUT_PATH.stat().st_size)
# Out:
# Writing to: C:\Users\Adam\Lazverbcon\laz_verb_conjugator\SQL Lazverbcon\verb_form_seed_stage.csv
# Exists? True
# Absolute path: C:\Users\Adam\Lazverbcon\laz_verb_conjugator\SQL Lazverbcon\verb_form_seed_stage.csv
# Last modified: 2026-03-03 02:32:22.476168394
# File size: 11860278

# %%
print("verbs_to_insert category counts:")
display(verbs_to_insert["verb_category_id"].value_counts())

print("cat_map:")
display(cat_map.head(10))
# Out:
# verbs_to_insert category counts:
# verb_category_id
# 2    434
# 1    137
# 3     82
# Name: count, dtype: int64
# cat_map:
#    verb_category_id code
# 0                 1  TVM
# 1                 2  TVE
# 2                 3  IVD
# 3                 4  TVM
# 4                 5  TVE
# 5                 6  IVD
# 6                 7  TVM
# 7                 8  TVE
# 8                 9  IVD
# 9                10  TVM

# %%
test_inf = "ot̆axu"  # TVE

for obj_setting in [None, "all"]:
    out = conjugate_verb(
        tense_modules=tense_modules,
        infinitive=test_inf,
        tense="past",
        aspect=None,
        obj=obj_setting,
        subject="all",
        optative=False,
        imperative=False,
        neg_imperative=False,
        applicative=False,
        causative=False,
        simple_causative=False,
    )

    print("\nobj =", obj_setting)
    print("meta exists_in_tve:", out.get("meta", {}).get("exists_in_tve"))
    print("meta selected:", out.get("meta", {}).get("selected"))
    print("result dialects:", list(out.get("result", {}).keys())[:4])

    # show what's inside each dialect (type + preview)
    for d in list(out.get("result", {}).keys())[:2]:
        val = out["result"][d]
        print(" ", d, "type:", type(val))
        if isinstance(val, dict):
            print("   frames:", list(val.keys()))
        else:
            print("   value preview:", str(val)[:200])
# Out:
# obj = None
# meta exists_in_tve: True
# meta selected: {'path': 'tense', 'ivd_mapping': {}, 'tve_mapping': {'present': ['tve_present'], 'past': ['tve_past'], 'future': ['tve_future'], 'pastpro': ['tve_pastpro']}, 'tvm_mapping': {}}
# result dialects: ['FA', 'AŞ', 'PZ', 'HO']
#   FA type: <class 'dict'>
#    frames: ['Ergative']
#   AŞ type: <class 'dict'>
#    frames: ['Ergative']
#
# obj = all
# meta exists_in_tve: True
# meta selected: {'path': 'tense', 'ivd_mapping': {}, 'tve_mapping': {'present': ['tve_present'], 'past': ['tve_past'], 'future': ['tve_future'], 'pastpro': ['tve_pastpro']}, 'tvm_mapping': {}}
# result dialects: ['FA', 'AŞ', 'PZ', 'HO']
#   FA type: <class 'dict'>
#    frames: ['Ergative']
#   AŞ type: <class 'dict'>
#    frames: ['Ergative']

# %%
df_out[df_out["category"]=="TVM"][["infinitive","tense","subject","object"]].head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_out[df_out["category"]=="TVM"][["infinitive","tense","subject","object"]].head(20)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'category'

# %%
print("File size (bytes):", OUT_PATH.stat().st_size)
